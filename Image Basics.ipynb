# %%
import matplotlib.pyplot as plt
img = plt.imread('/content/download.jpg')
print(type(img))
print(img.ndim)
print(img.shape)
print(img.min())
print(img.max())
print(img.dtype)
# Out:
# <class 'numpy.ndarray'>
# 3
# (266, 190, 3)
# 0
# 255
# uint8

# %%
# Every image is a Numpy array with different values
# Colored Image (RGB) have 3 Dimensions: Height,Width,Plane
# Gray scaled Images have 2 Dimensions : Height , Width
# Color values are from 0 to 255

# %%
import numpy as np
a = np.array([[1,2,3,7,12],
              [9,23,12,5,6]])
plt.imshow(a,cmap='gray')
